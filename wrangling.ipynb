# %%
#Import 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import os
import warnings

# %%
df= pd.read_csv("train.csv")
df
# Out:
#        Unnamed: 0           artist_name                     track_name  \
# 0               0                mukesh           mohabbat bhi jhoothi
# 1               4         frankie laine                      i believe
# 2               6           johnnie ray                            cry
# 3              10           pérez prado                       patricia
# 4              12  giorgos papadopoulos             apopse eida oneiro
# ...           ...                   ...                            ...
# 28357       82447               mack 10                10 million ways
# 28358       82448                m.o.p.  ante up (robbin hoodz theory)
# 28359       82449                  nine                  whutcha want?
# 28360       82450            will smith                         switch
# 28361       82451                 jeezy                         r.i.p.
#
#        release_date    genre  \
# 0              1950      pop
# 1              1950      pop
# ...

# %%
df.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
# ...

# %%
df.drop(columns=['lyrics'], inplace=True)

# %% [markdown]
# I dropped the lyrics column.

# %%
df.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#    len    dating  violence  world/life  night/time  ...  communication  \
# 0   95  0.000598  0.063746    0.000598    0.000598  ...       0.263751
# 1   51  0.035537  0.096777    0.443435    0.001284  ...       0.001284
# 2   24  0.002770  0.002770    0.002770    0.002770  ...       0.250668
# 3   54  0.048249  0.001548    0.001548    0.001548  ...       0.001548
# 4   48  0.001350  0.001350    0.417772    0.001350  ...       0.001350
#
#     obscene     music  movement/places  light/visual perceptions  \
# ...

# %%
selected_col =["age","violence","len","sadness", "family/spiritual","dating"]
plt.figure(figsize=(30, 20))
sns.heatmap(df[selected_col].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Heat maps provide a visual representation of data values in a matrix format, where each cell is assigned a color based on its numeric value. Heat maps are particularly useful for identifying patterns, trends, and relationships in large datasets.
